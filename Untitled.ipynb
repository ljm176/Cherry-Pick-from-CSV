# %%
import opentrons
# Out:
# C:\Users\lajamu\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\lajamu\.opentrons\robot_settings.json not found. Loading defaults
# Loading json containers...
# Json container file load complete, listing database
# Found 0 containers to add. Starting migration...
# Database migration complete!

# %%
# !opentrons_simulate make_glycerol_reformat.py
# Out:
# Loading json containers...
# Json container file load complete, listing database
# C:\Users\lajamu\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\lajamu\.opentrons\robot_settings.json not found. Loading defaults
# C:\Users\lajamu\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\lajamu\.opentrons\robot_settings.json not found. Loading defaults
# Found 0 containers to add. Starting migration...
# Database migration complete!
# Consolidating [100.0, 100.0] from A1 of Opentrons 6 Tube Rack with Falcon 50 mL Conical on 3 to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 6
# 	Transferring [100.0, 100.0] from A1 of Opentrons 6 Tube Rack with Falcon 50 mL Conical on 3 to A1 of Bio-Rad 96 Well Plate 200 µL PCR on 6
# 		Picking up tip from A1 of Opentrons 96 Tip Rack 300 µL on 2
# 		Aspirating 100.0 uL from A1 of Opentrons 6 Tube Rack with Falcon 50 mL Conical on 3 at 1.0 speed
# ...
